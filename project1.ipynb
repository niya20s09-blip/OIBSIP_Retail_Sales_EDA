# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5011f4d4-0bdc-4a4a-bce6-436beefb28f2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5011f4d4-0bdc-4a4a-bce6-436beefb28f2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv("/content/archive (1).zip")

df.head()
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# 3         1             500           500
# 4         2              50           100

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    1000 non-null   int64
#  1   Date              1000 non-null   object
#  2   Customer ID       1000 non-null   object
#  3   Gender            1000 non-null   object
#  4   Age               1000 non-null   int64
#  5   Product Category  1000 non-null   object
#  6   Quantity          1000 non-null   int64
#  7   Price per Unit    1000 non-null   int64
#  8   Total Amount      1000 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 70.4+ KB

# %%
df['Total Amount'].describe()
# Out:
# count    1000.000000
# mean      456.000000
# std       559.997632
# min        25.000000
# 25%        60.000000
# 50%       135.000000
# 75%       900.000000
# max      2000.000000
# Name: Total Amount, dtype: float64

# %%
import pandas as pd
df= pd.read_csv('/content/archive.zip')
print("Mean:", df['Total Amount'].mean())
print("Median:", df['Total Amount'].median())
print("Mode:", df['Total Amount'].mode()[0])
print("Standard Deviation:", df['Total Amount'].std())
# Out:
# Mean: 456.0
# Median: 135.0
# Mode: 50
# Standard Deviation: 559.997631555123

# %%
# converting the date to the date format
import pandas as pd
df= pd.read_csv('/content/archive.zip')
df['Date']= pd.to_datetime(df['Date'])
df= df.sort_values(by='Date')
sales_trend= df.groupby('Date')['Total Amount'].sum()
import matplotlib.pyplot as plt
plt.figure(figsize=(12,6))
sales_trend.plot()
plt.title('Sales Trend Over Time')
plt.xlabel('Date')
plt.ylabel('Total Amount')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('/content/archive.zip')
gender_sales= df.groupby('Gender')['Total Amount'].sum()
plt.figure(figsize=(8,6))
sns.barplot(x=gender_sales.index, y= gender_sales.values)
plt.title('Sales by Gender')
plt.xlabel('Gender')
plt.ylabel('Total Amount')



age_sales= df.groupby('Age')['Total Amount'].sum()
plt.figure(figsize=(12,6))
sns.histplot(data=df, x='Age', bins=20, kde=True)
plt.title('Sales by Age')
plt.xlabel('Age')
plt.ylabel('Total Amount')
plt.show()

df['age group']= pd.cut(df['Age'], bins=[0,18,30,45,60,100], labels=['teen', 'young adult', 'adult', 'senior', 'old'])
age_group_sales= df.groupby('age group')['Total Amount'].sum()
sns.barplot(x=age_group_sales.index, y= age_group_sales.values)
plt.show()
# Out:
# /tmp/ipykernel_302/2224825357.py:23: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   age_group_sales= df.groupby('age group')['Total Amount'].sum()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('/content/archive.zip')
product_sales= df.groupby('Product Category')['Total Amount'].sum()
plt.figure(figsize=(12,6))
sns.barplot(x=product_sales.index, y= product_sales.values)
plt.title('Sales by Product')
plt.xlabel('Product')
plt.ylabel('Total Amount')
plt.show()


product_quantity= df.groupby('Product Category')['Quantity'].sum()
plt.figure(figsize=(12,6))
sns.lineplot(x=product_quantity.index, y= product_quantity.values)
plt.title('Quantity Sold by Product')
plt.xlabel('Product')
plt.ylabel('Quantity')
plt.show()

# %% [markdown]
# Buisness Recommendations from EDA
# 1. target high spending age groups through various loyality programs, discounts, specialized marketing, sales initiatives etc.
# 2. Focus on low spending age groups to elevate their sales.
# 3. Gender based marketing strategies can also be implemented
# 4. Products with low sales should be more actively promoted with different sales strategy.
# 5. Seasonality planning for specific down seasons should be implemented
